# %% [markdown]
# <a href="https://colab.research.google.com/github/iksnn/Learn-Basic-Deep-Learning/blob/main/Text_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Referensi :
# *   Review Dataset : https://www.kaggle.com/datasets/grikomsn/lazada-indonesian-reviews
# *   Stoplist Dataset : https://www.kaggle.com/oswinrh/indonesian-stoplist
# *   Slang Word : https://github.com/okkyibrohim/id-multi-label-hate-speech-and-abusive-language-detection

# %% [markdown]
# # Preparing Library

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk

nltk.download('punkt')

from tqdm import tqdm
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Basic Text Processing

# %% [markdown]
# case folding

# %%
my_text = "hello world"
print(f"from:{my_text}, to:{my_text.title()}")
print(f"from:{my_text}, to:{my_text.upper()}")
my_text = "HELLO WORLD"
print(f"from:{my_text}, to:{my_text.lower()}")
# Out:
# from:hello world, to:Hello World
# from:hello world, to:HELLO WORLD
# from:HELLO WORLD, to:hello world

# %% [markdown]
# access text character

# %%
my_text = "hello world this is my text"
print(my_text[7])
print(my_text[:10])
print(my_text[10:])
print(my_text[10:15])
# Out:
# o
# hello worl
# d this is my text
# d thi

# %% [markdown]
# chunk text

# %%
my_text = "hello world this is my text"
print(my_text.split())
# Out:
# ['hello', 'world', 'this', 'is', 'my', 'text']

# %%
print(my_text.split(" "))
# Out:
# ['hello', 'world', 'this', 'is', 'my', 'text']

# %%
print(my_text.split("s"))
# Out:
# ['hello world thi', ' i', ' my text']

# %% [markdown]
# append text

# %%
text1 = "hello world"
text2 = "this is my text"
print(text1 + " " + text2)
# Out:
# hello world this is my text

# %% [markdown]
# # Preprocessing

# %%
folder_path = "/content/drive/MyDrive/MSIB Celerates Batch 7/Code Ipynb/40. EDA & Vectorization Techniques for Text Data/"

# %% [markdown]
# ## Preparing Data and Handle Missing Value

# %%
data = pd.read_csv(folder_path+'20191002-reviews.csv')
print(data.shape)
data.head()
# Out:
# (203787, 15)
#       itemId                 category             name  rating  \
# 0  100002528  beli-harddisk-eksternal         Kamal U.       5
# 1  100002528  beli-harddisk-eksternal       yofanca m.       4
# 2  100002528  beli-harddisk-eksternal  Lazada Customer       5
# 3  100002528  beli-harddisk-eksternal  Lazada Customer       4
# 4  100002528  beli-harddisk-eksternal         Yosep M.       5
#
#    originalRating                                  reviewTitle  \
# 0             NaN                                          NaN
# 1             NaN                                          NaN
# 2             NaN  ok mantaaapppp barang sesuai pesanan.. good
# 3             NaN                                          NaN
# 4             NaN                                          NaN
#
#                       reviewContent  likeCount  upVotes  downVotes  helpful  \
# 0   bagus  mantap dah sesui pesanan          0        0          0     True
# 1                Bagus, sesuai foto          0        0          0     True
# 2  okkkkk mantaaaaaaapppp ... goood          0        0          0     True
# 3                      bagus sesuai          0        0          0     True
# 4                               NaN          0        0          0     True
#
#    relevanceScore   boughtDate  clientType retrievedDate
# 0           26.51  09 Apr 2019  androidApp    2019-10-02
# 1           22.49  24 Sep 2017  androidApp    2019-10-02
# 2           21.50  04 Apr 2018  androidApp    2019-10-02
# 3           20.51  22 Sep 2017  androidApp    2019-10-02
# 4           16.01  17 Agu 2018  androidApp    2019-10-02

# %%
df = data[['reviewContent', 'rating']]
print(df.shape)
df.head()
# Out:
# (203787, 2)
#                       reviewContent  rating
# 0   bagus  mantap dah sesui pesanan       5
# 1                Bagus, sesuai foto       4
# 2  okkkkk mantaaaaaaapppp ... goood       5
# 3                      bagus sesuai       4
# 4                               NaN       5

# %%
df.isnull().sum()
# Out:
# reviewContent    96758
# rating               0
# dtype: int64

# %%
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# reviewContent    0
# rating           0
# dtype: int64

# %%
print(df.shape)
df.head()
# Out:
# (107029, 2)
#                       reviewContent  rating
# 0   bagus  mantap dah sesui pesanan       5
# 1                Bagus, sesuai foto       4
# 2  okkkkk mantaaaaaaapppp ... goood       5
# 3                      bagus sesuai       4
# 4                              bima       1

# %% [markdown]
# ## Regex Sentence

# %%
text_preproc1 = []
for i in tqdm(range(df.shape[0])):
  x = df['reviewContent'][i]
  y = df['rating'][i]
  pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
  x = x.lower()
  x = re.sub(pattern,' ',x) #remove urls if any
  x = re.sub(r'[^.,a-zA-Z0-9 \n\.]',' ',x) #remove symbol
  x = re.sub('[\s]+', ' ', x) #menghilangkan additional whitespace
  x = re.sub(r'[^\w\s]','',x) #remove punctuation
  x = x.strip() #menghilangkan enter, tab, dll
  hasil = str(x),y
  text_preproc1.append(hasil)
# Out:
# 100%|██████████| 107029/107029 [00:06<00:00, 15885.20it/s]

# %%
len(text_preproc1)
# Out:
# 107029

# %%
df1 = pd.DataFrame(text_preproc1, columns=['text_preproc1', 'rating'])
df1.head()
# Out:
#                     text_preproc1  rating
# 0  bagus mantap dah sesui pesanan       5
# 1               bagus sesuai foto       4
# 2   okkkkk mantaaaaaaapppp  goood       5
# 3                    bagus sesuai       4
# 4                            bima       1

# %% [markdown]
# ## Stopword and Slangword with file

# %%
fSlang = folder_path+'new_kamusalay.csv'
sw = open(fSlang, encoding='utf-8', errors ='ignore', mode='r');SlangS = sw.readlines(); sw.close()
SlangS = {slang.strip().split(',')[0]:slang.strip().split(',')[1] for slang in SlangS}

# %%
fStop = folder_path+'stopwordbahasa.csv'
st = open(fStop, encoding='utf-8', errors ='ignore', mode='r');StopS = st.readlines(); st.close()
StopS = {Stop.strip() for Stop in StopS}

# %%
def formaldanstop(t):
  t = t.split()
  for i,x in enumerate(t):
    if x in SlangS.keys():
      t[i] = SlangS[x]
  return ''.join(' '.join(x for x in t if x not in StopS))

# %%
df1['text_preproc2'] = df1['text_preproc1'].map(formaldanstop)
df1.head()
# Out:
#                     text_preproc1  rating                 text_preproc2
# 0  bagus mantap dah sesui pesanan       5    bagus mantap sesui pesanan
# 1               bagus sesuai foto       4             bagus sesuai foto
# 2   okkkkk mantaaaaaaapppp  goood       5  okkkkk mantaaaaaaapppp goood
# 3                    bagus sesuai       4                  bagus sesuai
# 4                            bima       1                          bima

# %% [markdown]
# ## Stopword and Stemming from Sastrawi

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

stopword = StopWordRemoverFactory().create_stop_word_remover()
stemmer = StemmerFactory().create_stemmer()

# %%
clean_text = []
for i,kalimat in tqdm(enumerate(df1['text_preproc2'])):
  stop = stopword.remove(kalimat)
  stem = stemmer.stem(stop)
  # if i%10000 ==0:
  #   print('loading kalimat ke:',i,'dari',len(df1['text_preproc2']))
  clean_text.append(stem)
# Out:
# 107029it [1:15:45, 23.55it/s]

# %%
df1['clean_text'] = clean_text
df2 = df1[['clean_text','rating']]
df2.head()
# Out:
#       itemId                 category             name  rating  \
# 0  100002528  beli-harddisk-eksternal         Kamal U.       5
# 1  100002528  beli-harddisk-eksternal       yofanca m.       4
# 2  100002528  beli-harddisk-eksternal  Lazada Customer       5
# 3  100002528  beli-harddisk-eksternal  Lazada Customer       4
# 4  100002528  beli-harddisk-eksternal         Yosep M.       5
#
#    originalRating                                  reviewTitle  \
# 0             NaN                                          NaN
# 1             NaN                                          NaN
# 2             NaN  ok mantaaapppp barang sesuai pesanan.. good
# 3             NaN                                          NaN
# 4             NaN                                          NaN
#
#                       reviewContent  likeCount  upVotes  downVotes  helpful  \
# 0   bagus  mantap dah sesui pesanan          0        0          0     True
# 1                Bagus, sesuai foto          0        0          0     True
# 2  okkkkk mantaaaaaaapppp ... goood          0        0          0     True
# 3                      bagus sesuai          0        0          0     True
# 4                               NaN          0        0          0     True
#
#    relevanceScore   boughtDate  clientType retrievedDate
# 0           26.51  09 Apr 2019  androidApp    2019-10-02
# 1           22.49  24 Sep 2017  androidApp    2019-10-02
# 2           21.50  04 Apr 2018  androidApp    2019-10-02
# 3           20.51  22 Sep 2017  androidApp    2019-10-02
# 4           16.01  17 Agu 2018  androidApp    2019-10-02

# %%
df2.to_csv(folder_path+'clean_text.csv', index=False)
